# %% [markdown]
# # Week 6B Class

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
plot1 = sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)

# %%
import matplotlib.pyplot as plt 
plt.show(plot1)

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(plot1.figure)



# Source: https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d157e517f75e> in <module>
#       1 fig, axs = plt.subplots(2)
#       2 fig.suptitle('Vertically stacked subplots')
# ----> 3 axs[0].plot(plot1.figure)
#       4
#       5
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# -> 1607             self.add_line(line)
#    1608         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609         return lines
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    2103             line.set_clip_path(self.patch)
#    2104
# -> 2105         self._update_line_limits(line)
#    2106         if not line.get_label():
#    2107             line.set_label('_line%d' % len(self.lines))
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    2125         Figures out the data limit of the given line, updating self.dataLim.
#    2126         """
# -> 2127         path = line.get_path()
#    2128         if path.vertices.size == 0:
#    2129             return
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/lines.py in recache(self, always)
#     666         if always or self._invalidy:
#     667             yconv = self.convert_yunits(self._yorig)
# --> 668             y = _to_unmasked_float_array(yconv).ravel()
#     669         else:
#     670             y = self._y
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1331         return np.ma.asarray(x, float).filled(np.nan)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#    1335
#
# ~/.pyenv/versions/3.8.3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'Figure'
